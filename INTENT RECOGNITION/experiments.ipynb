# %%
from intent_recognition import *

# %%
# EXERCICI 4 BÀSIC
tf.keras.utils.set_random_seed(42)
hyperparams = {'vocab_size': 500, 'embedding_dim': 1024, 'epochs': 10, 'batch_size': 64}

train_config = {'use_class_weights': True}


model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), merge_mode="ave"))
model.add(GlobalMaxPooling1D())
model.add(Dense(64, activation="relu"))
basic = IntentRecognition(model, hyperparams, train_config=train_config, training_times=1, verbosing=1, name="testing", save_results=False)
basic.train_model()
basic.print_training_information()
basic.evaluate_model()
#basic.view_wrong_predictions()
# Out:
# Number of classes in training data: 22
# Training model 1/1Epoch 1/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.0267 - f1_score: 0.0199 - loss: 3.1372 - val_accuracy: 0.3444 - val_f1_score: 0.0839 - val_loss: 2.9155
# Epoch 2/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.2238 - f1_score: 0.1662 - loss: 2.9670 - val_accuracy: 0.5233 - val_f1_score: 0.2678 - val_loss: 2.4767
# Epoch 3/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.6604 - f1_score: 0.3140 - loss: 2.4972 - val_accuracy: 0.7478 - val_f1_score: 0.3386 - val_loss: 1.7147
# Epoch 4/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.8294 - f1_score: 0.4268 - loss: 1.7767 - val_accuracy: 0.6556 - val_f1_score: 0.4078 - val_loss: 1.3995
# Epoch 5/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.7158 - f1_score: 0.4670 - loss: 1.1830 - val_accuracy: 0.7844 - val_f1_score: 0.4663 - val_loss: 0.8991
# Epoch 6/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8323 - f1_score: 0.5638 - loss: 0.7909 - val_accuracy: 0.8489 - val_f1_score: 0.5152 - val_loss: 0.6596
# Epoch 7/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.8811 - f1_score: 0.6310 - loss: 0.4224 - val_accuracy: 0.8667 - val_f1_score: 0.5240 - val_loss: 0.5070
# Epoch 8/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9145 - f1_score: 0.6819 - loss: 0.2276 - val_accuracy: 0.8911 - val_f1_score: 0.5378 - val_loss: 0.3948
# Epoch 9/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9372 - f1_score: 0.7179 - loss: 0.1471 - val_accuracy: 0.9278 - val_f1_score: 0.5618 - val_loss: 0.3095
# Epoch 10/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9533 - f1_score: 0.7644 - loss: 0.1058 - val_accuracy: 0.9311 - val_f1_score: 0.5588 - val_loss: 0.2678
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 13
#      11 model.add(Dense(64, activation="relu"))
#      12 basic = IntentRecognition(model, hyperparams, train_config=train_config, training_times=1, verbosing=1, name="testing", save_results=False)
# ---> 13 basic.train_model()
#      14 basic.print_training_information()
#      15 basic.evaluate_model()
#
# File c:\Users\Usuario\Documents\Universitat\5_Quatri\TVD\frame-based\frame-based-system\INTENT RECOGNITION\intent_recognition.py:331, in IntentRecognition.train_model(self)
#     329         if not self.architecture_name.startswith("Bidirectional"):
#     330             best_model = tf.keras.models.clone_model(self.model)
# --> 331             best_model.set_weights(self.model.get_weights())
#     332 else:
#     333     if val_f1 > best_val_f1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\layer.py:657, in Layer.set_weights(self, weights)
#     655 layer_weights = self.weights
#     656 if len(layer_weights) != len(weights):
# --> 657     raise ValueError(
#     658         f"You called `set_weights(weights)` on layer '{self.name}' "
#     659         f"with a weight list of length {len(weights)}, but the layer "
#     660         f"was expecting {len(layer_weights)} weights."
#     661     )
#     662 for variable, value in zip(layer_weights, weights):
#     663     if variable.shape != value.shape:
#
# ValueError: You called `set_weights(weights)` on layer 'sequential_1' with a weight list of length 11, but the layer was expecting 14 weights.

# %%
print(basic.class_weights_dict)
# Out:
# {0: 1.5446969696969697, 1: 2.7259358288770055, 2: 185.36363636363637, 3: 0.5566475566475566, 4: 185.36363636363637, 5: 1.482909090909091, 6: 92.68181818181819, 7: 13.24025974025974, 8: 14.258741258741258, 9: 185.36363636363637, 10: 11.585227272727273, 11: 12.357575757575757, 12: 0.06131777583977385, 13: 12.357575757575757, 14: 16.85123966942149, 15: 4.029644268774703, 16: 12.357575757575757, 17: 0.9131213613972234, 18: 185.36363636363637, 19: 61.78787878787879, 20: 3.707272727272727, 21: 92.68181818181819}

# %%
Average Training Accuracy: 0.9970573782920837
Average Training F1: 0.9021275043487549
Average Training Loss: 0.012978216633200645
Average Validation Accuracy: 0.9688888788223267
Average Validation F1: 0.6097612977027893
Average Validation Loss: 0.13441801071166992
Best Model Validation Accuracy: 0.9688888788223267
Best Model Validation F1: 0.6097612977027893

Evaluating model...
28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9593 - f1_score: 0.4792 - loss: 0.1576
Test accuracy: 0.9594594836235046
Test Macro F1: 0.590165376663208

# %%
model = Sequential()
model.add(Embedding(500, 256))  # Embedding layer
model.add(Bidirectional(LSTM(16, return_sequences=True)))
model.add(GlobalMaxPooling1D())
model.add(Dense(22, activation="softmax"))  # Output layer

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model and capture the training history
history = model.fit(
    basic.train_pad_sequences, 
    basic.train_encoded_labels, 
    batch_size=basic.hyperparams['batch_size'], 
    epochs=basic.hyperparams['epochs'], 
    validation_data=(basic.val_pad_sequences, basic.val_encoded_labels),
    verbose=basic.verbosing
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = Sequential()
#       2 model.add(Embedding(500, 256))  # Embedding layer
#       3 model.add(Bidirectional(LSTM(16, return_sequences=True)))
#
# NameError: name 'Sequential' is not defined

# %%
best_model = tf.keras.models.clone_model(model)
best_model.set_weights(model.get_weights())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 best_model = tf.keras.models.clone_model(model)
# ----> 2 best_model.set_weights(model.get_weights())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\layer.py:657, in Layer.set_weights(self, weights)
#     655 layer_weights = self.weights
#     656 if len(layer_weights) != len(weights):
# --> 657     raise ValueError(
#     658         f"You called `set_weights(weights)` on layer '{self.name}' "
#     659         f"with a weight list of length {len(weights)}, but the layer "
#     660         f"was expecting {len(layer_weights)} weights."
#     661     )
#     662 for variable, value in zip(layer_weights, weights):
#     663     if variable.shape != value.shape:
#
# ValueError: You called `set_weights(weights)` on layer 'sequential_3' with a weight list of length 15, but the layer was expecting 21 weights.

# %%
import sys
import os

# Add the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from plot_functions import *
import pandas as pd
df = pd.read_csv('./preprocessing.csv_complete.csv')

plot_name_metrics(df, "k", metric="val_f1")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 from plot_functions import *
#       2 import pandas as pd
# ----> 3 df = pd.read_csv('./preprocessing.csv_complete.csv')
#       5 plot_name_metrics(df, "k", metric="val_f1")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:624, in _read(filepath_or_buffer, kwds)
#     621     return parser
#     623 with parser:
# --> 624     return parser.read(nrows)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1921, in TextFileReader.read(self, nrows)
#    1914 nrows = validate_integer("nrows", nrows)
#    1915 try:
#    1916     # error: "ParserBase" has no attribute "read"
#    1917     (
#    1918         index,
#    1919         columns,
#    1920         col_dict,
# -> 1921     ) = self._engine.read(  # type: ignore[attr-defined]
#    1922         nrows
#    1923     )
#    1924 except Exception:
#    1925     self.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
plot_highest_bar(df, metric="Val_f1")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plot_highest_bar(df, metric="Val_f1")
#
# File c:\Users\Usuario\Documents\Universitat\5_Quatri\TVD\frame-based\frame-based-system\plot_functions.py:37, in plot_highest_bar(df, metric)
#      36 def plot_highest_bar(df, metric='val_acc'):
# ---> 37     max_metrics = df.groupby('architecture_name')[metric].max().reset_index()
#      38     max_metrics = max_metrics.sort_values(by=metric, ascending=False)
#      40     colors = [
#      41     "#FFADAD",  # Soft Pink
#      42     "#FFD6A5",  # Peach
#    (...)
#      65     "#E4C1F9"   # Pale Lilac
#      66 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Val_f1'

# %%
plot_compare_architectures(df, metric="training_loss")

# %%
plot_train_val_comparison(df, 'ConvLSTM_Max', metric='f1', comparison_type='all')
