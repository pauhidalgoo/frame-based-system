# %%
from ner import *
from final_refine import *
from transformer_prof import *
from tqdm import tqdm

# %%
model_types
# Out:
# ['BidirectionalGRU_128_01', 'BidirectionalGRU_256_01', 'BidirectionalGRU_256']

# %%
embedding_sizes = [2048]
vocab_size = [1000]
class_weights = [True]
paddings = ["post"]

# Total combinations of hyperparameters for tqdm progress bar
total_iterations = len(embedding_sizes) * len(vocab_size) * len(class_weights) * len(model_types) * len(paddings)

# Wrapping the outer loop with tqdm to display the total progress
with tqdm(total=total_iterations, desc="Training Models") as pbar:
    for emb_size in embedding_sizes:
        for voc_size in vocab_size:
            for clss_w in class_weights:
                for pad in paddings:
                    train_config = {'use_sample_weights': clss_w}
                    hyperparams = {
                        'vocab_size': voc_size, 
                        'embedding_dim': emb_size, 
                        'epochs': 20, 
                        'batch_size': 64
                    }

                    preprocessing_config = {'lemmatize':False, 'stem':True, 'remove_stopwords':False, 'custom_stopwords':None, 'padding':pad}

                    name = "BidirectionalGRU_256_01"
                    model = create_model(name)
                    basic = NamedEntityRecognition(
                        model, 
                        hyperparams, 
                        training_times=1, 
                        train_config=train_config, 
                        verbosing=0, 
                        name=name,
                        results_file_name="./results/NER_refining"
                    )
                    basic.train_model()
                    basic.print_training_information()
                    
                    # Update the progress bar after each model training iteration
                    pbar.update(1)
# Out:
# Training Models:   0%|          | 0/3 [00:00<?, ?it/s]
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step
# 897
# 897
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
# Training Models:  33%|███▎      | 1/3 [09:35<19:11, 575.86s/it]
# Average Training Accuracy: 0.9966471195220947
# Average Training F1: 0.4038776159286499
# Average Training Loss: 0.004274995531886816
# Average Validation Accuracy: 0.9896029829978943
# Average Validation F1: 0.34930193424224854
# Average Validation Loss: 0.08173242956399918
# Best Model Validation Accuracy: 0.9896029829978943
# Best Model Validation F1: 0.34930193424224854

# %%
basic.evaluate_model()
# Out:
# Evaluating model...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 basic.evaluate_model()
#
# File c:\Users\Usuario\Documents\Universitat\5_Quatri\TVD\frame-based\frame-based-system\NAME ENTITY RECOGNITION\ner.py:559, in NamedEntityRecognition.evaluate_model(self)
#     554 """
#     555 Evaluates the trained model on the test data and prints the accuracy.
#     556 Note: This evaluates the last trained model.
#     557 """
#     558 print('Evaluating model...')
# --> 559 loss, accuracy, f1 = self.model.evaluate(
#     560     self.test_pad_sequences,
#     561     self.test_labels_one_hot,
#     562     batch_size=self.hyperparams['batch_size']
#     563 )
#     565 f1 = np.mean(f1)
#     566 print(f"Test accuracy: {accuracy}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\data_adapter_utils.py:114, in check_data_cardinality(data)
#     110     sizes = ", ".join(
#     111         str(i.shape[0]) for i in tree.flatten(single_data)
#     112     )
#     113     msg += f"'{label}' sizes: {sizes}\n"
# --> 114 raise ValueError(msg)
#
# ValueError: Data cardinality is ambiguous. Make sure all arrays contain the same number of samples.'x' sizes: 885
# 'y' sizes: 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46, 46

# %%
loss, accuracy, f1 = basic.model.evaluate(
    basic.test_pad_sequences, 
    basic.test_labels_one_hot, 
    batch_size=basic.hyperparams['batch_size']
)

f1 = np.mean(f1)
print(f"Test accuracy: {accuracy}")
print(f"Test Macro F1: {f1}")
print(self.classification_report(basic.model, basic.test_pad_sequences, basic.test_sequences, basic.test_labels_one_hot))
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      